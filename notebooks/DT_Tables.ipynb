# %% [markdown]
# # Dimension tables

# %%
import uuid

# %% [markdown]
# ## DT_Time

# %%
import pandas as pd
from datetime import datetime, timedelta


actual_date = datetime.now()


beginning_date = actual_date - timedelta(days=365*3)


data = []


date_1 = beginning_date
while date_1 <= actual_date:
    id_date = date_1.strftime("%Y%m%d")  
    date = date_1.strftime("%Y-%m-%d") 
    calendar_year = date_1.strftime("%Y") 
    calendar_year_month = date_1.strftime("%Y%m") 
    calendar_year_week = date_1.strftime("%Y%W") 
    day_week_of_year = date_1.isocalendar()[1]  
    month_of_year = date_1.month  
    
    # Agregar los datos de la fila a la lista
    data.append((id_date, date, calendar_year, calendar_year_month, calendar_year_week, day_week_of_year, month_of_year))
    
    # Avanzar al siguiente día
    date_1 += timedelta(days=1)

# Crear el DataFrame
df_dt_time = pd.DataFrame(data, columns=['id_date', 'Date', 'CalendarYear', 'CalendarYearMonth', 'CalendarYearWeek', 'DayWeekOfYear', 'MonthOfYear'])

# Mostrar las primeras filas del DataFrame
df_dt_time
# Out:
#        id_date        Date CalendarYear CalendarYearMonth CalendarYearWeek  \
# 0     20210421  2021-04-21         2021            202104           202116
# 1     20210422  2021-04-22         2021            202104           202116
# 2     20210423  2021-04-23         2021            202104           202116
# 3     20210424  2021-04-24         2021            202104           202116
# 4     20210425  2021-04-25         2021            202104           202116
# ...        ...         ...          ...               ...              ...
# 1091  20240416  2024-04-16         2024            202404           202416
# 1092  20240417  2024-04-17         2024            202404           202416
# 1093  20240418  2024-04-18         2024            202404           202416
# 1094  20240419  2024-04-19         2024            202404           202416
# 1095  20240420  2024-04-20         2024            202404           202416
#
#       DayWeekOfYear  MonthOfYear
# 0                16            4
# 1                16            4
# 2                16            4
# 3                16            4
# 4                16            4
# ...             ...          ...
# 1091             16            4
# 1092             16            4
# 1093             16            4
# 1094             16            4
# 1095             16            4
#
# [1096 rows x 7 columns]

# %%
import mysql.connector

connection = mysql.connector.connect(
    user = 'root',
    password = 'root',
    host = 'localhost',
    port = 3306,
    database = 'Historical_Data'
)
print("MySQL DB Connected")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\eneko\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:268, in CMySQLConnection._open_connection(self)
#     267 try:
# --> 268     self._cmysql.connect(**cnx_kwargs)
#     269     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Lost connection to MySQL server at 'reading initial communication packet', system error: 0
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In [2], line 3
#       1 import mysql.connector
# ----> 3 connection = mysql.connector.connect(
#       4     user = 'root',
#       5     password = 'root',
#       6     host = 'localhost',
#       7     port = 8806,
#       8     database = 'Historical_Data'
#       9 )
#      10 print("MySQL DB Connected")
#
# File c:\Users\eneko\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\pooling.py:286, in connect(*args, **kwargs)
#     283         raise ImportError(ERROR_NO_CEXT)
#     285 if CMySQLConnection and not use_pure:
# --> 286     return CMySQLConnection(*args, **kwargs)
#     287 return MySQLConnection(*args, **kwargs)
#
# File c:\Users\eneko\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:101, in CMySQLConnection.__init__(self, **kwargs)
#      98 super().__init__()
#     100 if kwargs:
# --> 101     self.connect(**kwargs)
#
# File c:\Users\eneko\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\abstracts.py:1108, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1105     self.config(**kwargs)
#    1107 self.disconnect()
# -> 1108 self._open_connection()
#    1109 # Server does not allow to run any other statement different from ALTER
#    1110 # when user's password has been expired.
#    1111 if not self._client_flags & ClientFlag.CAN_HANDLE_EXPIRED_PASSWORDS:
#
# File c:\Users\eneko\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:273, in CMySQLConnection._open_connection(self)
#     271         self.converter.str_fallback = self._converter_str_fallback
#     272 except MySQLInterfaceError as err:
# --> 273     raise get_mysql_exception(
#     274         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     275     ) from err
#     277 self._do_handshake()
#
# OperationalError: 2013 (HY000): Lost connection to MySQL server at 'reading initial communication packet', system error: 0

# %%
cursor = connection.cursor()


# SQL Consult
sql_insert = """
    INSERT INTO DT_TIME (id_date, Date, CalendarYear, CalendarYearMonth, CalendarYearWeek, DayWeekOfYear, MonthOfYear)
    VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

try:
    # Iterate on the dataframe
    for index, row in df_dt_time.iterrows():
        cursor.execute(sql_insert, tuple(row))
    
    # Confirm the changes on the database
    connection.commit()
    print("Data inserted correctly.")
except mysql.connector.Error as error:
    # Error
    print("Error inserting the DT_TIME data:", error)
    connection.rollback()

# Close the cursor and the connection
cursor.close()
connection.close()
# Out:
# Data inserted correctly.

# %% [markdown]
# ## DT_Exchanges

# %%
import mysql.connector

connection = mysql.connector.connect(
    user = 'root',
    password = 'root',
    host = 'localhost',
    port = 3306,
    database = 'Historical_Data'
)
print("MySQL DB Connected")
# Out:
# MySQL DB Connected

# %%
criptos = [
    {"exchange_1": "BTC", "exchange_2": "USD", "creation_date": "2009-01-03"},
    {"exchange_1": "ETH", "exchange_2": "USD", "creation_date": "2015-07-30"},
    {"exchange_1": "XRP", "exchange_2": "USD", "creation_date": "2012-08-01"},
    {"exchange_1": "LTC", "exchange_2": "USD", "creation_date": "2011-10-07"},
    {"exchange_1": "BCH", "exchange_2": "USD", "creation_date": "2017-08-01"},
    {"exchange_1": "LINK", "exchange_2": "USD", "creation_date": "2017-09-19"},
    {"exchange_1": "ADA", "exchange_2": "USD", "creation_date": "2017-09-29"},
    {"exchange_1": "DOT", "exchange_2": "USD", "creation_date": "2020-05-26"},
    {"exchange_1": "XLM", "exchange_2": "USD", "creation_date": "2014-07-31"},
    {"exchange_1": "USDT", "exchange_2": "USD", "creation_date": "2014-09-10"},
    {"exchange_1": "BSV", "exchange_2": "USD", "creation_date": "2018-11-15"},
    {"exchange_1": "UNI", "exchange_2": "USD", "creation_date": "2020-09-17"},
    {"exchange_1": "DOGE", "exchange_2": "USD", "creation_date": "2013-12-06"},
    {"exchange_1": "AVAX", "exchange_2": "USD", "creation_date": "2020-09-21"},
    {"exchange_1": "EOS", "exchange_2": "USD", "creation_date": "2018-06-25"},
    {"exchange_1": "TRX", "exchange_2": "USD", "creation_date": "2017-09-13"},
    {"exchange_1": "ATOM", "exchange_2": "USD", "creation_date": "2019-03-13"},
    {"exchange_1": "XMR", "exchange_2": "USD", "creation_date": "2014-04-18"},
    {"exchange_1": "XTZ", "exchange_2": "USD", "creation_date": "2018-06-30"},
    {"exchange_1": "AAVE", "exchange_2": "USD", "creation_date": "2020-10-02"},
    {"exchange_1": "SNX", "exchange_2": "USD", "creation_date": "2017-09-26"},
    {"exchange_1": "SOL", "exchange_2": "USD", "creation_date": "2020-03-20"},
    {"exchange_1": "NEO", "exchange_2": "USD", "creation_date": "2014-02-09"},
    {"exchange_1": "LEO", "exchange_2": "USD", "creation_date": "2019-05-22"},
    {"exchange_1": "XEM", "exchange_2": "USD", "creation_date": "2015-03-31"},
    {"exchange_1": "VET", "exchange_2": "USD", "creation_date": "2018-08-26"},
    {"exchange_1": "FTT", "exchange_2": "USD", "creation_date": "2019-05-30"},
    {"exchange_1": "THETA", "exchange_2": "USD", "creation_date": "2019-01-23"},
    {"exchange_1": "MKR", "exchange_2": "USD", "creation_date": "2017-12-18"},
    {"exchange_1": "HT", "exchange_2": "USD", "creation_date": "2019-01-31"},
    {"exchange_1": "MIOTA", "exchange_2": "USD", "creation_date": "2015-06-13"},
    {"exchange_1": "SNM", "exchange_2": "USD", "creation_date": "2017-06-12"},
    {"exchange_1": "CRO", "exchange_2": "USD", "creation_date": "2017-06-30"},
    {"exchange_1": "RUNE", "exchange_2": "USD", "creation_date": "2019-07-27"},
    {"exchange_1": "WAVES", "exchange_2": "USD", "creation_date": "2016-06-02"},
    {"exchange_1": "COMP", "exchange_2": "USD", "creation_date": "2020-06-15"},
    {"exchange_1": "HBAR", "exchange_2": "USD", "creation_date": "2019-07-06"},
    {"exchange_1": "THETA", "exchange_2": "USD", "creation_date": "2019-01-23"},
    {"exchange_1": "FTM", "exchange_2": "USD", "creation_date": "2018-12-11"},
    {"exchange_1": "GRT", "exchange_2": "USD", "creation_date": "2020-12-15"},
    {"exchange_1": "ETC", "exchange_2": "USD", "creation_date": "2015-07-24"},
    {"exchange_1": "DASH", "exchange_2": "USD", "creation_date": "2014-01-18"},
    {"exchange_1": "ZEC", "exchange_2": "USD", "creation_date": "2016-10-28"},
    {"exchange_1": "BAT", "exchange_2": "USD", "creation_date": "2017-05-31"},
    {"exchange_1": "SUSHI", "exchange_2": "USD", "creation_date": "2020-08-26"},
    {"exchange_1": "YFI", "exchange_2": "USD", "creation_date": "2020-07-17"},
    {"exchange_1": "SNX", "exchange_2": "USD", "creation_date": "2017-09-26"},
    {"exchange_1": "REN", "exchange_2": "USD", "creation_date": "2018-02-20"}
]

# %%
# Add the concatenation:
for cripto in criptos:
    cripto["exchange"] = cripto["exchange_1"] + "-" + cripto["exchange_2"]

criptos
# Out:
# [{'exchange_1': 'BTC',
#   'exchange_2': 'USD',
#   'creation_date': '2009-01-03',
#   'exchange': 'BTC-USD'},
#  {'exchange_1': 'ETH',
#   'exchange_2': 'USD',
#   'creation_date': '2015-07-30',
#   'exchange': 'ETH-USD'},
#  {'exchange_1': 'XRP',
#   'exchange_2': 'USD',
#   'creation_date': '2012-08-01',
#   'exchange': 'XRP-USD'},
#  {'exchange_1': 'LTC',
#   'exchange_2': 'USD',
#   'creation_date': '2011-10-07',
#   'exchange': 'LTC-USD'},
#  {'exchange_1': 'BCH',
#   'exchange_2': 'USD',
#   'creation_date': '2017-08-01',
#   'exchange': 'BCH-USD'},
#  {'exchange_1': 'LINK',
#   'exchange_2': 'USD',
#   'creation_date': '2017-09-19',
#   'exchange': 'LINK-USD'},
#  {'exchange_1': 'ADA',
#   'exchange_2': 'USD',
#   'creation_date': '2017-09-29',
#   'exchange': 'ADA-USD'},
#  {'exchange_1': 'DOT',
#   'exchange_2': 'USD',
#   'creation_date': '2020-05-26',
#   'exchange': 'DOT-USD'},
#  {'exchange_1': 'XLM',
#   'exchange_2': 'USD',
#   'creation_date': '2014-07-31',
#   'exchange': 'XLM-USD'},
#  {'exchange_1': 'USDT',
#   'exchange_2': 'USD',
#   'creation_date': '2014-09-10',
#   'exchange': 'USDT-USD'},
#  {'exchange_1': 'BSV',
#   'exchange_2': 'USD',
#   'creation_date': '2018-11-15',
#   'exchange': 'BSV-USD'},
#  {'exchange_1': 'UNI',
#   'exchange_2': 'USD',
#   'creation_date': '2020-09-17',
#   'exchange': 'UNI-USD'},
#  {'exchange_1': 'DOGE',
#   'exchange_2': 'USD',
#   'creation_date': '2013-12-06',
#   'exchange': 'DOGE-USD'},
#  {'exchange_1': 'AVAX',
#   'exchange_2': 'USD',
#   'creation_date': '2020-09-21',
#   'exchange': 'AVAX-USD'},
#  {'exchange_1': 'EOS',
#   'exchange_2': 'USD',
#   'creation_date': '2018-06-25',
#   'exchange': 'EOS-USD'},
#  {'exchange_1': 'TRX',
#   'exchange_2': 'USD',
#   'creation_date': '2017-09-13',
#   'exchange': 'TRX-USD'},
#  {'exchange_1': 'ATOM',
#   'exchange_2': 'USD',
#   'creation_date': '2019-03-13',
#   'exchange': 'ATOM-USD'},
#  {'exchange_1': 'XMR',
#   'exchange_2': 'USD',
#   'creation_date': '2014-04-18',
#   'exchange': 'XMR-USD'},
#  {'exchange_1': 'XTZ',
#   'exchange_2': 'USD',
#   'creation_date': '2018-06-30',
#   'exchange': 'XTZ-USD'},
#  {'exchange_1': 'AAVE',
#   'exchange_2': 'USD',
#   'creation_date': '2020-10-02',
#   'exchange': 'AAVE-USD'},
#  {'exchange_1': 'SNX',
#   'exchange_2': 'USD',
#   'creation_date': '2017-09-26',
#   'exchange': 'SNX-USD'},
#  {'exchange_1': 'SOL',
#   'exchange_2': 'USD',
#   'creation_date': '2020-03-20',
#   'exchange': 'SOL-USD'},
#  {'exchange_1': 'NEO',
#   'exchange_2': 'USD',
#   'creation_date': '2014-02-09',
#   'exchange': 'NEO-USD'},
#  {'exchange_1': 'LEO',
#   'exchange_2': 'USD',
#   'creation_date': '2019-05-22',
#   'exchange': 'LEO-USD'},
#  {'exchange_1': 'XEM',
#   'exchange_2': 'USD',
#   'creation_date': '2015-03-31',
#   'exchange': 'XEM-USD'},
#  {'exchange_1': 'VET',
#   'exchange_2': 'USD',
#   'creation_date': '2018-08-26',
#   'exchange': 'VET-USD'},
#  {'exchange_1': 'FTT',
#   'exchange_2': 'USD',
#   'creation_date': '2019-05-30',
#   'exchange': 'FTT-USD'},
#  {'exchange_1': 'THETA',
#   'exchange_2': 'USD',
#   'creation_date': '2019-01-23',
#   'exchange': 'THETA-USD'},
#  {'exchange_1': 'MKR',
#   'exchange_2': 'USD',
#   'creation_date': '2017-12-18',
#   'exchange': 'MKR-USD'},
#  {'exchange_1': 'HT',
#   'exchange_2': 'USD',
#   'creation_date': '2019-01-31',
#   'exchange': 'HT-USD'},
#  {'exchange_1': 'MIOTA',
#   'exchange_2': 'USD',
#   'creation_date': '2015-06-13',
#   'exchange': 'MIOTA-USD'},
#  {'exchange_1': 'SNM',
#   'exchange_2': 'USD',
#   'creation_date': '2017-06-12',
#   'exchange': 'SNM-USD'},
#  {'exchange_1': 'CRO',
#   'exchange_2': 'USD',
#   'creation_date': '2017-06-30',
#   'exchange': 'CRO-USD'},
#  {'exchange_1': 'RUNE',
#   'exchange_2': 'USD',
#   'creation_date': '2019-07-27',
#   'exchange': 'RUNE-USD'},
#  {'exchange_1': 'WAVES',
#   'exchange_2': 'USD',
#   'creation_date': '2016-06-02',
#   'exchange': 'WAVES-USD'},
#  {'exchange_1': 'COMP',
#   'exchange_2': 'USD',
#   'creation_date': '2020-06-15',
#   'exchange': 'COMP-USD'},
#  {'exchange_1': 'HBAR',
#   'exchange_2': 'USD',
#   'creation_date': '2019-07-06',
#   'exchange': 'HBAR-USD'},
#  {'exchange_1': 'THETA',
#   'exchange_2': 'USD',
#   'creation_date': '2019-01-23',
#   'exchange': 'THETA-USD'},
#  {'exchange_1': 'FTM',
#   'exchange_2': 'USD',
#   'creation_date': '2018-12-11',
#   'exchange': 'FTM-USD'},
#  {'exchange_1': 'GRT',
#   'exchange_2': 'USD',
#   'creation_date': '2020-12-15',
#   'exchange': 'GRT-USD'},
#  {'exchange_1': 'ETC',
#   'exchange_2': 'USD',
#   'creation_date': '2015-07-24',
#   'exchange': 'ETC-USD'},
#  {'exchange_1': 'DASH',
#   'exchange_2': 'USD',
#   'creation_date': '2014-01-18',
#   'exchange': 'DASH-USD'},
#  {'exchange_1': 'ZEC',
#   'exchange_2': 'USD',
#   'creation_date': '2016-10-28',
#   'exchange': 'ZEC-USD'},
#  {'exchange_1': 'BAT',
#   'exchange_2': 'USD',
#   'creation_date': '2017-05-31',
#   'exchange': 'BAT-USD'},
#  {'exchange_1': 'SUSHI',
#   'exchange_2': 'USD',
#   'creation_date': '2020-08-26',
#   'exchange': 'SUSHI-USD'},
#  {'exchange_1': 'YFI',
#   'exchange_2': 'USD',
#   'creation_date': '2020-07-17',
#   'exchange': 'YFI-USD'},
#  {'exchange_1': 'SNX',
#   'exchange_2': 'USD',
#   'creation_date': '2017-09-26',
#   'exchange': 'SNX-USD'},
#  {'exchange_1': 'REN',
#   'exchange_2': 'USD',
#   'creation_date': '2018-02-20',
#   'exchange': 'REN-USD'}]

# %%
cursor = connection.cursor()

# SQL Consult
sql_insert_exchange = """
    INSERT INTO DT_EXCHANGES (exchange_1, exchange_2, creation_date, exchange)
    VALUES (%s, %s, %s, %s)
"""


try:
    # Iterar sobre las criptomonedas y ejecutar la consulta para insertarlas en la tabla
    for cripto in criptos:

        # Ejecutar la consulta de inserción
        cursor.execute(sql_insert_exchange, (cripto["exchange_1"], cripto["exchange_2"], cripto["creation_date"], cripto["exchange"]))
    
    # Confirmar los cambios en la base de datos
    connection.commit()
    print("Data inserted correctly.")
except mysql.connector.Error as error:
    # Error
    print("Error inserting the DT_EXCHANGE data:", error)
    connection.rollback()

# Cerrar el cursor y la conexión
cursor.close()
connection.close()
# Out:
# Data inserted correctly.
